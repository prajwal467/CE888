# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
recom = pd.read_csv('https://raw.githubusercontent.com/albanda/CE888/master/lab4-recommender/jester-data-1.csv', header=None)
recom.head()
# Out:
#    0      1      2      3      4    ...    96     97     98     99     100
# 0   74  -7.82   8.79  -9.66  -8.16  ...  99.00  -5.63  99.00  99.00  99.00
# 1  100   4.08  -0.29   6.36   4.37  ...  -2.14   3.06   0.34  -4.32   1.07
# 2   49  99.00  99.00  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 3   48  99.00   8.35  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 4   91   8.50   4.61  -4.17  -5.39  ...   1.55   3.11   6.55   1.80   1.60
#
# [5 rows x 101 columns]

# %%
recom.describe().transpose()
# Out:
#        count       mean        std    min     25%    50%    75%    max
# 0    24983.0  72.467478  21.859600  36.00  53.000  72.00  100.0  100.0
# 1    24983.0  34.401435  46.707059  -9.95  -0.150   5.05   99.0   99.0
# 2    24983.0  27.094089  44.228006  -9.95  -2.180   3.69   99.0   99.0
# 3    24983.0  33.263717  46.747535  -9.95  -1.145   4.66   99.0   99.0
# 4    24983.0  36.244936  48.812967  -9.95  -3.350   3.45   99.0   99.0
# ..       ...        ...        ...    ...     ...    ...    ...    ...
# 96   24983.0  58.541104  48.130562  -9.95   3.300  99.00   99.0   99.0
# 97   24983.0  58.017246  48.164681  -9.95   3.590  99.00   99.0   99.0
# 98   24983.0  57.061650  48.717455  -9.95   2.670  99.00   99.0   99.0
# 99   24983.0  55.753357  49.237139  -9.95   1.335  99.00   99.0   99.0
# 100  24983.0  60.138090  47.913531  -9.95   3.930  99.00   99.0   99.0
#
# [101 rows x 8 columns]

# %%
recom_nan = recom.replace(99, np.nan)

# %%
recom_nan.isna().sum()
# Out:
# 0         81
# 1       8531
# 2       6799
# 3       8341
# 4       9375
#        ...
# 96     14613
# 97     14463
# 98     14317
# 99     14073
# 100    15040
# Length: 101, dtype: int64

# %%
len(recom[0].unique())
# Out:
# 65

# %%
recom_nan.drop(columns=0, axis=1, inplace=True)

# %%
recom_nan.head()
# Out:
#     1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0 -7.82  8.79 -9.66 -8.16 -7.52 -8.50  ...   NaN   NaN -5.63   NaN   NaN   NaN
# 1  4.08 -0.29  6.36  4.37 -2.38 -9.66  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 2   NaN   NaN   NaN   NaN  9.03  9.27  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  8.35   NaN   NaN  1.80  8.16  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4  8.50  4.61 -4.17 -5.39  1.36  1.60  ...  5.73  1.55  3.11  6.55  1.80  1.60
#
# [5 rows x 100 columns]

# %%
recom_nan.mean().sort_values(ascending=True)
# Out:
# 58   -3.833880
# 16   -3.104818
# 44   -2.111891
# 57   -1.990664
# 13   -1.762882
#         ...
# 32    3.155988
# 27    3.189821
# 36    3.312500
# 89    3.574720
# 50    3.665085
# Length: 100, dtype: float64

# %%
arr_1 = recom_nan.values

# %%
np.where(arr_1!= 99)
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([ 0,  1,  2, ..., 97, 98, 99]))

# %%
def helper_function(orig, percentage=0.1):
  """
  Replaces 'percentage'% of the original values in 'orig' with 99's
  :param orig: original data array
  :param percentage: percentage of values to replace (0<percentage<1)
  """
  new_data = orig.copy()
  rated = np.where(~np.isnan(orig))
  n_rated = len(rated[0])
  idx = np.random.choice(n_rated, size=int(percentage*n_rated), replace=False)
  new_data[rated[0][idx], rated[1][idx]] = 99
  return new_data, (rated[0][idx], rated[1][idx])

# %%
new_arr, idx = helper_function(arr_1)

# %%
arr_1[idx[0][0], idx[1][0]]
# Out:
# -5.63

# %%
new_arr[idx[0][0], idx[1][0]]
# Out:
# 99.0

# %%
recom.groupby(0).count()
# Out:
#       1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0                                        ...
# 36    482   482   482   482   482   482  ...   482   482   482   482   482   482
# 37    409   409   409   409   409   409  ...   409   409   409   409   409   409
# 38    413   413   413   413   413   413  ...   413   413   413   413   413   413
# 39    391   391   391   391   391   391  ...   391   391   391   391   391   391
# 40    407   407   407   407   407   407  ...   407   407   407   407   407   407
# ..    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 96     68    68    68    68    68    68  ...    68    68    68    68    68    68
# 97     60    60    60    60    60    60  ...    60    60    60    60    60    60
# 98     71    71    71    71    71    71  ...    71    71    71    71    71    71
# 99     81    81    81    81    81    81  ...    81    81    81    81    81    81
# 100  7200  7200  7200  7200  7200  7200  ...  7200  7200  7200  7200  7200  7200
#
# [65 rows x 100 columns]

# %%
users = recom[0].unique()
users
# Out:
# array([ 74, 100,  49,  48,  91,  47,  72,  36,  51,  53,  55,  50,  67,
#         60,  54,  46,  38,  41,  73,  92,  89,  71,  40,  45,  62,  63,
#         61,  65,  68,  69,  37,  56,  66,  64,  82,  57,  75,  88,  86,
#         43,  83,  93,  94,  44,  59,  39,  58,  70,  78,  97,  90,  84,
#         98,  96,  52,  80,  42,  81,  76,  79,  85,  77,  95,  87,  99])

# %%
def predict_rating(user_id, item_id):
    """ Predict a rating given a user_id and an item_id.
    """
    user_preference = latent_user_preferences[user_id]
    item_preference = latent_item_features[item_id]
    return user_preference.dot(item_preference)


def train(user_id, item_id, rating, alpha=0.0001):
    #print(item_id)
    predicted_rating = predict_rating(user_id, item_id)
    err =  predicted_rating - rating
    #print(err)
    user_pref_values = latent_user_preferences[user_id]
    latent_user_preferences[user_id] -= alpha * err * latent_item_features[item_id]
    latent_item_features[item_id] -= alpha * err * user_pref_values
    return err
    

def sgd(iterations):
    """ Iterate over all users and all items and train for 
        a certain number of iterations
    """
    mse_history = []
    for iteration in range(iterations):
        error = []
        for user_id in range(latent_user_preferences.shape[0]):
            for item_id in range(latent_item_features.shape[0]):
                rating = user_ratings[user_id, item_id]
                if not np.isnan(rating):
                    err = train(user_id, item_id, rating)
                    error.append(err)
        mse = (np.array(error) ** 2).mean()   
        if (iteration % 5) == 0:
            print('Iteration %d/%d:\tMSE=%.6f' % (iteration, iterations, mse))
            mse_history.append(mse)
    return mse_history

# %%
n_latent_factors = 4

user_ratings = recom_nan.values
# Initialise as random values
latent_user_preferences = np.random.random((user_ratings.shape[0], n_latent_factors))
latent_item_features = np.random.random((user_ratings.shape[1], n_latent_factors))

# %%
err  =[]
for u, i in zip(*idx):
  err.append(predict_rating(u,i) - user_ratings[u,i])
print('MSE of validation set: ', (np.array(err)**2).mean())
# Out:
# MSE of validation set:  27.663525299933795

# %%
test_idx = np.where(np.isnan(user_ratings))
for u, i in zip(*test_idx):
  print('Prediction for {} user_id for item_id {} is {}'.format(u, i, predict_rating(u,i)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Prediction for 24812 user_id for item_id 92 is 1.000588068062231
# Prediction for 24812 user_id for item_id 93 is 0.8899621287467092
# Prediction for 24812 user_id for item_id 94 is 0.6806186741670722
# Prediction for 24812 user_id for item_id 95 is 0.6665937577246955
# Prediction for 24813 user_id for item_id 70 is 1.156661115230541
# Prediction for 24813 user_id for item_id 71 is 0.8863218157734349
# Prediction for 24813 user_id for item_id 72 is 1.390015308825449
# Prediction for 24813 user_id for item_id 73 is 1.1293066111423629
# Prediction for 24813 user_id for item_id 74 is 0.9543116935608417
# Prediction for 24813 user_id for item_id 75 is 1.2757984854197755
# Prediction for 24813 user_id for item_id 76 is 0.8671079551021188
# Prediction for 24813 user_id for item_id 77 is 0.45298659076792486
# Prediction for 24813 user_id for item_id 78 is 0.9859448777128659
# Prediction for 24813 user_id for item_id 79 is 0.6176151522939326
# Prediction for 24813 user_id for item_id 80 is 0.5826985908289617
# Prediction for 24813 user_id for item_id 81 is 0.4412892236455058
# Prediction for 24813 user_id for item_id 83 is 0.6433605935079337
# Prediction for 24813 user_id for item_id 85 is 1.191176437783173
# Prediction for 24813 user_id for item_id 86 is 0.7120535797486603
# Prediction for 24813 user_id for item_id 87 is 1.2613817730549286
# Prediction for 24813 user_id for item_id 88 is 0.6474281562602662
# Prediction for 24813 user_id for item_id 89 is 0.42810782416273524
# Prediction for 24813 user_id for item_id 90 is 0.4774224484988743
# Prediction for 24813 user_id for item_id 91 is 1.0897640937989002
# Prediction for 24813 user_id for item_id 92 is 0.9060418536009608
# Prediction for 24813 user_id for item_id 93 is 0.7752040061059923
# Prediction for 24813 user_id for item_id 95 is 0.6759597004510829
# Prediction for 24813 user_id for item_id 96 is 0.7826083522478723
# Prediction for 24813 user_id for item_id 97 is 0.4755509868873052
# Prediction for 24813 user_id for item_id 98 is 0.35104549195645385
# Prediction for 24813 user_id for item_id 99 is 0.948208982882174
# Prediction for 24814 user_id for item_id 0 is 0.25977308325136034
# Prediction for 24814 user_id for item_id 1 is 0.8687100360952895
# Prediction for 24814 user_id for item_id 2 is 1.32154543090224
# Prediction for 24814 user_id for item_id 3 is 0.5154740591198682
# Prediction for 24814 user_id for item_id 5 is 0.871638857152577
# Prediction for 24814 user_id for item_id 8 is 1.0159216035125753
# Prediction for 24814 user_id for item_id 9 is 0.9315863743157298
# Prediction for 24814 user_id for item_id 10 is 0.8810260468505017
# Prediction for 24814 user_id for item_id 11 is 1.0972065474041686
# Prediction for 24814 user_id for item_id 13 is 0.427866582440072
# Prediction for 24814 user_id for item_id 21 is 1.196390243171772
# Prediction for 24814 user_id for item_id 22 is 0.9051297813779695
# Prediction for 24814 user_id for item_id 23 is 1.7762437133979363
# Prediction for 24814 user_id for item_id 24 is 0.8920053365543421
# Prediction for 24814 user_id for item_id 25 is 1.2193576582383803
# Prediction for 24814 user_id for item_id 28 is 0.7192821134387135
# Prediction for 24814 user_id for item_id 29 is 1.5603808579304665
# Prediction for 24814 user_id for item_id 32 is 0.9186263444810789
# Prediction for 24814 user_id for item_id 36 is 1.4852012165583939
# Prediction for 24814 user_id for item_id 37 is 0.557624497083342
# Prediction for 24814 user_id for item_id 38 is 1.04212852170008
# Prediction for 24814 user_id for item_id 40 is 0.8539916491090632
# Prediction for 24814 user_id for item_id 42 is 0.44140017911294754
# Prediction for 24814 user_id for item_id 43 is 0.6216780426892147
# Prediction for 24814 user_id for item_id 44 is 0.9425638117700316
# Prediction for 24814 user_id for item_id 50 is 0.7120838578913334
# Prediction for 24814 user_id for item_id 51 is 1.2631875200809233
# Prediction for 24814 user_id for item_id 53 is 0.8310350619000773
# Prediction for 24814 user_id for item_id 54 is 0.9299966596121874
# Prediction for 24814 user_id for item_id 56 is 1.2740151868694778
# Prediction for 24814 user_id for item_id 57 is 0.591537476911907
# Prediction for 24814 user_id for item_id 58 is 1.2088468216825732
# Prediction for 24814 user_id for item_id 59 is 1.429302698508786
# Prediction for 24814 user_id for item_id 62 is 1.2994024247068794
# Prediction for 24814 user_id for item_id 63 is 1.2561453306015447
# Prediction for 24814 user_id for item_id 66 is 0.5342364567280612
# Prediction for 24814 user_id for item_id 71 is 1.1802897877749172
# Prediction for 24814 user_id for item_id 72 is 1.7340974087478322
# Prediction for 24814 user_id for item_id 73 is 1.0551309165969653
# Prediction for 24814 user_id for item_id 74 is 1.0009171873663245
# Prediction for 24814 user_id for item_id 75 is 1.5375669948306951
# Prediction for 24814 user_id for item_id 76 is 0.8736334275073685
# Prediction for 24814 user_id for item_id 77 is 0.40515550368131015
# Prediction for 24814 user_id for item_id 78 is 0.8977507434365234
# Prediction for 24814 user_id for item_id 79 is 0.5460553502171923
# Prediction for 24814 user_id for item_id 80 is 0.7362557132480361
# Prediction for 24814 user_id for item_id 81 is 0.5229921670554416
# Prediction for 24814 user_id for item_id 82 is 1.0014239898922541
# Prediction for 24814 user_id for item_id 83 is 0.730782416425775
# Prediction for 24814 user_id for item_id 84 is 1.1971397571838676
# Prediction for 24814 user_id for item_id 85 is 1.532373805295923
# Prediction for 24814 user_id for item_id 87 is 1.2426840440236628
# Prediction for 24814 user_id for item_id 88 is 0.6546465557425294
# Prediction for 24814 user_id for item_id 89 is 0.25107831500864425
# Prediction for 24814 user_id for item_id 90 is 0.3245985980641073
# Prediction for 24814 user_id for item_id 91 is 1.5161267392301214
# Prediction for 24814 user_id for item_id 92 is 0.974516997272153
# Prediction for 24814 user_id for item_id 93 is 1.0845095863907965
# Prediction for 24814 user_id for item_id 95 is 0.6769705131978133
# Prediction for 24814 user_id for item_id 96 is 0.805002624337563
# Prediction for 24814 user_id for item_id 97 is 0.28923302860692457
# Prediction for 24814 user_id for item_id 98 is 0.18217468747436444
# Prediction for 24814 user_id for item_id 99 is 0.8353401125765457
# Prediction for 24815 user_id for item_id 70 is 1.423385608154123
# Prediction for 24815 user_id for item_id 71 is 0.8154149034432678
# Prediction for 24815 user_id for item_id 72 is 1.1219376991535024
# Prediction for 24815 user_id for item_id 73 is 1.421346404439443
# Prediction for 24815 user_id for item_id 74 is 1.208205168632409
# Prediction for 24815 user_id for item_id 75 is 1.508971148148894
# Prediction for 24815 user_id for item_id 76 is 1.1644960207222255
# Prediction for 24815 user_id for item_id 77 is 0.8633767576320612
# Prediction for 24815 user_id for item_id 78 is 1.3368172351580665
# Prediction for 24815 user_id for item_id 79 is 0.8365118063319623
# Prediction for 24815 user_id for item_id 80 is 0.4666782207440294
# Prediction for 24815 user_id for item_id 81 is 0.4815815991988618
# Prediction for 24815 user_id for item_id 82 is 1.0453187102391732
# Prediction for 24815 user_id for item_id 83 is 0.5643077855663331
# Prediction for 24815 user_id for item_id 84 is 1.3403480372775463
# Prediction for 24815 user_id for item_id 85 is 1.1458739259980926
# Prediction for 24815 user_id for item_id 87 is 1.5367860854840272
# Prediction for 24815 user_id for item_id 88 is 0.8757842207786973
# Prediction for 24815 user_id for item_id 89 is 0.7743959243151377
# Prediction for 24815 user_id for item_id 90 is 0.8542795891393705
# Prediction for 24815 user_id for item_id 91 is 0.7540902318798942
# Prediction for 24815 user_id for item_id 92 is 1.300538745096776
# Prediction for 24815 user_id for item_id 93 is 0.7088799207850262
# Prediction for 24815 user_id for item_id 94 is 0.6926971461818732
# Prediction for 24815 user_id for item_id 95 is 1.105420173603905
# Prediction for 24815 user_id for item_id 97 is 0.6186073507923994
# Prediction for 24815 user_id for item_id 98 is 0.612076067624201
# Prediction for 24815 user_id for item_id 99 is 1.3829112129803773
# Prediction for 24816 user_id for item_id 0 is 0.4327181271277592
# Prediction for 24816 user_id for item_id 1 is 0.8015774440938116
# Prediction for 24816 user_id for item_id 2 is 0.8654179315620548
# Prediction for 24816 user_id for item_id 3 is 1.0276254156761817
# Prediction for 24816 user_id for item_id 8 is 0.980123180648208
# Prediction for 24816 user_id for item_id 9 is 0.5986084575343034
# Prediction for 24816 user_id for item_id 11 is 1.1611084244312206
# Prediction for 24816 user_id for item_id 21 is 1.2707958306206601
# Prediction for 24816 user_id for item_id 22 is 0.41280460200949987
# Prediction for 24816 user_id for item_id 23 is 1.4816416993287702
# Prediction for 24816 user_id for item_id 24 is 0.5242131474047099
# Prediction for 24816 user_id for item_id 29 is 1.382852292932644
# Prediction for 24816 user_id for item_id 32 is 0.869785559423107
# Prediction for 24816 user_id for item_id 33 is 1.272737924962851
# Prediction for 24816 user_id for item_id 36 is 0.9640850116229635
# Prediction for 24816 user_id for item_id 37 is 0.7814136952575375
# Prediction for 24816 user_id for item_id 40 is 0.9326635357001065
# Prediction for 24816 user_id for item_id 42 is 0.4086467624450309
# Prediction for 24816 user_id for item_id 43 is 0.5645053765650868
# Prediction for 24816 user_id for item_id 44 is 1.2513960888841786
# Prediction for 24816 user_id for item_id 45 is 0.8557526342667966
# Prediction for 24816 user_id for item_id 46 is 0.6667579134689372
# Prediction for 24816 user_id for item_id 50 is 1.0012763648392693
# Prediction for 24816 user_id for item_id 54 is 0.9632934561140403
# Prediction for 24816 user_id for item_id 57 is 1.054275496304958
# Prediction for 24816 user_id for item_id 58 is 1.1133294492772265
# Prediction for 24816 user_id for item_id 59 is 0.985912650315554
# Prediction for 24816 user_id for item_id 62 is 1.207983659979452
# Prediction for 24816 user_id for item_id 63 is 1.0035602698263473
# Prediction for 24816 user_id for item_id 66 is 0.7878721285547512
# Prediction for 24816 user_id for item_id 69 is 0.7413140556259277
# Prediction for 24816 user_id for item_id 70 is 1.1154423619931773
# Prediction for 24816 user_id for item_id 71 is 0.6956509625779672
# Prediction for 24816 user_id for item_id 72 is 1.3424956123715337
# Prediction for 24816 user_id for item_id 73 is 1.1766546187477849
# Prediction for 24816 user_id for item_id 74 is 0.8516886418193844
# Prediction for 24816 user_id for item_id 75 is 0.9875621070814739
# Prediction for 24816 user_id for item_id 76 is 0.8191580260450919
# Prediction for 24816 user_id for item_id 77 is 0.40321967093645006
# Prediction for 24816 user_id for item_id 78 is 1.1969476750555768
# Prediction for 24816 user_id for item_id 79 is 0.8102795058923868
# Prediction for 24816 user_id for item_id 80 is 0.47975623408131035
# Prediction for 24816 user_id for item_id 81 is 0.45043545631301685
# Prediction for 24816 user_id for item_id 82 is 1.2166815159905247
# Prediction for 24816 user_id for item_id 83 is 0.6200802062775127
# Prediction for 24816 user_id for item_id 84 is 0.9458719858945804
# Prediction for 24816 user_id for item_id 85 is 0.9828404305725567
# Prediction for 24816 user_id for item_id 86 is 0.6980897930460244
# Prediction for 24816 user_id for item_id 87 is 1.3799017712025912
# Prediction for 24816 user_id for item_id 88 is 0.584479822648888
# Prediction for 24816 user_id for item_id 89 is 0.6093768935308828
# Prediction for 24816 user_id for item_id 90 is 0.5704861773475548
# Prediction for 24816 user_id for item_id 91 is 0.8521212623981371
# Prediction for 24816 user_id for item_id 92 is 0.9277845386558092
# Prediction for 24816 user_id for item_id 93 is 0.60522270218859
# Prediction for 24816 user_id for item_id 94 is 0.6048522704792801
# Prediction for 24816 user_id for item_id 95 is 0.6571723059191845
# Prediction for 24816 user_id for item_id 97 is 0.7368787502809863
# Prediction for 24816 user_id for item_id 99 is 0.975189706450965
# Prediction for 24817 user_id for item_id 0 is 0.6505421608080463
# Prediction for 24817 user_id for item_id 2 is 0.9653787166750211
# Prediction for 24817 user_id for item_id 3 is 1.1703698759211425
# Prediction for 24817 user_id for item_id 8 is 0.79175572828153
# Prediction for 24817 user_id for item_id 23 is 1.1780508051275964
# Prediction for 24817 user_id for item_id 36 is 1.080036819769818
# Prediction for 24817 user_id for item_id 43 is 0.5093375017894303
# Prediction for 24817 user_id for item_id 56 is 0.9130688651733855
# Prediction for 24817 user_id for item_id 57 is 1.1599319093249059
# Prediction for 24817 user_id for item_id 70 is 1.2502226157637881
# Prediction for 24817 user_id for item_id 71 is 0.7454810234915477
# Prediction for 24817 user_id for item_id 73 is 1.1800359916606544
# Prediction for 24817 user_id for item_id 74 is 0.9752381138732237
# Prediction for 24817 user_id for item_id 75 is 1.2552210998959161
# Prediction for 24817 user_id for item_id 76 is 0.9818203236495121
# Prediction for 24817 user_id for item_id 77 is 0.7380073429623722
# Prediction for 24817 user_id for item_id 78 is 1.3507044645994877
# Prediction for 24817 user_id for item_id 79 is 0.9025988145176327
# Prediction for 24817 user_id for item_id 80 is 0.3707204339221921
# Prediction for 24817 user_id for item_id 81 is 0.5153710638688611
# Prediction for 24817 user_id for item_id 82 is 0.9196207627975023
# Prediction for 24817 user_id for item_id 84 is 1.1782199587099242
# Prediction for 24817 user_id for item_id 85 is 1.0525362144252437
# Prediction for 24817 user_id for item_id 86 is 0.7583894721024064
# Prediction for 24817 user_id for item_id 87 is 1.435082452803203
# Prediction for 24817 user_id for item_id 88 is 0.7081132375307699
# Prediction for 24817 user_id for item_id 89 is 0.7567635439685594
# Prediction for 24817 user_id for item_id 90 is 0.7501664608842844
# Prediction for 24817 user_id for item_id 91 is 0.6825438084551544
# Prediction for 24817 user_id for item_id 92 is 1.3240079531378135
# Prediction for 24817 user_id for item_id 93 is 0.719206070271136
# Prediction for 24817 user_id for item_id 94 is 0.6035395331028415
# Prediction for 24817 user_id for item_id 95 is 1.0435417432335452
# Prediction for 24817 user_id for item_id 96 is 0.9746136753967405
# Prediction for 24817 user_id for item_id 97 is 0.6203032455203431
# Prediction for 24817 user_id for item_id 98 is 0.6197949621516654
# Prediction for 24817 user_id for item_id 99 is 1.1471064766910095
# Prediction for 24818 user_id for item_id 0 is 0.7424905408606892
# Prediction for 24818 user_id for item_id 1 is 1.2822479160607143
# Prediction for 24818 user_id for item_id 2 is 1.4418592574536784
# Prediction for 24818 user_id for item_id 3 is 0.9853946184227231
# Prediction for 24818 user_id for item_id 5 is 1.0758092017288252
# Prediction for 24818 user_id for item_id 8 is 0.8328366021222414
# Prediction for 24818 user_id for item_id 9 is 0.9591413139720443
# Prediction for 24818 user_id for item_id 10 is 1.345806225665061
# Prediction for 24818 user_id for item_id 11 is 0.965733049446511
# Prediction for 24818 user_id for item_id 13 is 0.9382920314415134
# Prediction for 24818 user_id for item_id 21 is 1.2199677680455927
# Prediction for 24818 user_id for item_id 22 is 0.931555187233164
# Prediction for 24818 user_id for item_id 23 is 1.275565221323027
# Prediction for 24818 user_id for item_id 24 is 1.0799020794885659
# Prediction for 24818 user_id for item_id 25 is 1.2674137446829734
# Prediction for 24818 user_id for item_id 28 is 1.2220337834619166
# Prediction for 24818 user_id for item_id 29 is 1.3898609552320798
# Prediction for 24818 user_id for item_id 30 is 0.8535464351316292
# Prediction for 24818 user_id for item_id 32 is 1.0642756753423535
# Prediction for 24818 user_id for item_id 36 is 1.5500946551956387
# Prediction for 24818 user_id for item_id 37 is 0.40322165103601787
# Prediction for 24818 user_id for item_id 38 is 1.3747873083628737
# Prediction for 24818 user_id for item_id 40 is 1.009598424345176
# Prediction for 24818 user_id for item_id 43 is 0.5819236007653995
# Prediction for 24818 user_id for item_id 44 is 1.4628486486342027
# Prediction for 24818 user_id for item_id 45 is 0.5646623325748849
# Prediction for 24818 user_id for item_id 50 is 0.8512023686482355
# Prediction for 24818 user_id for item_id 51 is 1.6765901732880495
# Prediction for 24818 user_id for item_id 54 is 1.067729987286248
# Prediction for 24818 user_id for item_id 56 is 1.127499802292465
# Prediction for 24818 user_id for item_id 58 is 0.8459690847424451
# Prediction for 24818 user_id for item_id 59 is 1.7305238181980906
# Prediction for 24818 user_id for item_id 62 is 1.5722449315566984
# Prediction for 24818 user_id for item_id 63 is 1.0397300306086004
# Prediction for 24818 user_id for item_id 66 is 1.0634366507469057
# Prediction for 24818 user_id for item_id 70 is 1.5023414225789151
# Prediction for 24818 user_id for item_id 71 is 1.1088450657867255
# Prediction for 24818 user_id for item_id 72 is 1.3103850453645762
# Prediction for 24818 user_id for item_id 73 is 1.2966539011270197
# Prediction for 24818 user_id for item_id 74 is 1.279401558241121
# Prediction for 24818 user_id for item_id 75 is 1.862767554420018
# Prediction for 24818 user_id for item_id 76 is 1.2132359574854135
# Prediction for 24818 user_id for item_id 77 is 0.9558982834276707
# Prediction for 24818 user_id for item_id 78 is 1.2608623313553098
# Prediction for 24818 user_id for item_id 79 is 0.7658962688522519
# Prediction for 24818 user_id for item_id 80 is 0.5523199141700229
# Prediction for 24818 user_id for item_id 82 is 0.796952157954926
# Prediction for 24818 user_id for item_id 83 is 0.5579344695038118
# Prediction for 24818 user_id for item_id 84 is 1.5405287215238024
# Prediction for 24818 user_id for item_id 85 is 1.4839216177288657
# Prediction for 24818 user_id for item_id 86 is 0.8785201136340572
# Prediction for 24818 user_id for item_id 87 is 1.4799506800131779
# Prediction for 24818 user_id for item_id 88 is 0.9177387069087284
# Prediction for 24818 user_id for item_id 89 is 0.6333833807399074
# Prediction for 24818 user_id for item_id 90 is 0.7574534946142152
# Prediction for 24818 user_id for item_id 91 is 1.0725274681299446
# Prediction for 24818 user_id for item_id 92 is 1.5121672409616258
# Prediction for 24818 user_id for item_id 93 is 1.0504871521933055
# Prediction for 24818 user_id for item_id 94 is 0.62813456965739
# Prediction for 24818 user_id for item_id 95 is 1.2584574950588607
# Prediction for 24818 user_id for item_id 97 is 0.3371200153341395
# Prediction for 24818 user_id for item_id 98 is 0.44648871621773667
# Prediction for 24818 user_id for item_id 99 is 1.307434061545237
# Prediction for 24821 user_id for item_id 0 is 0.5147781093031251
# Prediction for 24821 user_id for item_id 2 is 0.7692313277799155
# Prediction for 24821 user_id for item_id 3 is 1.2643687433234927
# Prediction for 24821 user_id for item_id 8 is 1.025639901741666
# Prediction for 24821 user_id for item_id 23 is 1.4836064919917187
# Prediction for 24821 user_id for item_id 29 is 1.4185871901483555
# Prediction for 24821 user_id for item_id 32 is 0.9157202103825234
# Prediction for 24821 user_id for item_id 36 is 0.8602583485376963
# Prediction for 24821 user_id for item_id 37 is 0.9067694672007273
# Prediction for 24821 user_id for item_id 40 is 1.0103650540053783
# Prediction for 24821 user_id for item_id 42 is 0.41775154112009194
# Prediction for 24821 user_id for item_id 43 is 0.5799629142051198
# Prediction for 24821 user_id for item_id 54 is 1.0247069700782059
# Prediction for 24821 user_id for item_id 56 is 1.0025857097396442
# Prediction for 24821 user_id for item_id 57 is 1.2765012395645026
# Prediction for 24821 user_id for item_id 58 is 1.1531301490823136
# Prediction for 24821 user_id for item_id 59 is 0.912232128497278
# Prediction for 24821 user_id for item_id 63 is 0.994643814135163
# Prediction for 24821 user_id for item_id 66 is 0.9304379648127595
# Prediction for 24821 user_id for item_id 69 is 0.842245973076909
# Prediction for 24821 user_id for item_id 70 is 1.1540422207379393
# Prediction for 24821 user_id for item_id 71 is 0.5879080446419381
# Prediction for 24821 user_id for item_id 72 is 1.3071325716235762
# Prediction for 24821 user_id for item_id 73 is 1.2826873588260825
# Prediction for 24821 user_id for item_id 74 is 0.8530309877441277
# Prediction for 24821 user_id for item_id 75 is 0.8743458314421588
# Prediction for 24821 user_id for item_id 76 is 0.8528034115237512
# Prediction for 24821 user_id for item_id 77 is 0.4332191678592247
# Prediction for 24821 user_id for item_id 78 is 1.3822695755617762
# Prediction for 24821 user_id for item_id 79 is 0.9586854909212218
# Prediction for 24821 user_id for item_id 80 is 0.42256080546930047
# Prediction for 24821 user_id for item_id 81 is 0.46348512574939293
# Prediction for 24821 user_id for item_id 82 is 1.3536310095336281
# Prediction for 24821 user_id for item_id 83 is 0.6183659937471278
# Prediction for 24821 user_id for item_id 84 is 0.9294995605979596
# Prediction for 24821 user_id for item_id 85 is 0.8738780747103866
# Prediction for 24821 user_id for item_id 86 is 0.6994492070781557
# Prediction for 24821 user_id for item_id 87 is 1.5160797160059456
# Prediction for 24821 user_id for item_id 88 is 0.5963262053845738
# Prediction for 24821 user_id for item_id 89 is 0.7696368626484212
# Prediction for 24821 user_id for item_id 90 is 0.6876102190274792
# Prediction for 24821 user_id for item_id 91 is 0.6916066001290817
# Prediction for 24821 user_id for item_id 92 is 0.9923532956991954
# Prediction for 24821 user_id for item_id 93 is 0.5000471156187077
# Prediction for 24821 user_id for item_id 94 is 0.668255275742207
# Prediction for 24821 user_id for item_id 95 is 0.705233153522105
# Prediction for 24821 user_id for item_id 96 is 0.7431152164138799
# Prediction for 24821 user_id for item_id 97 is 0.9276410164141279
# Prediction for 24821 user_id for item_id 98 is 0.7046661656691605
# Prediction for 24821 user_id for item_id 99 is 1.0783625444389913
# Prediction for 24822 user_id for item_id 0 is 0.48391556053036033
# Prediction for 24822 user_id for item_id 1 is 1.024462074324726
# Prediction for 24822 user_id for item_id 2 is 1.4293763064969423
# Prediction for 24822 user_id for item_id 3 is 0.8406314078122872
# Prediction for 24822 user_id for item_id 5 is 0.9886953150872271
# Prediction for 24822 user_id for item_id 8 is 1.1168227091989702
# Prediction for 24822 user_id for item_id 9 is 0.940128705150394
# Prediction for 24822 user_id for item_id 10 is 1.03242403127148
# Prediction for 24822 user_id for item_id 11 is 1.236960503204854
# Prediction for 24822 user_id for item_id 13 is 0.6859521559000805
# Prediction for 24822 user_id for item_id 21 is 1.3786796610606655
# Prediction for 24822 user_id for item_id 23 is 1.795774193055081
# Prediction for 24822 user_id for item_id 24 is 0.9242696964601892
# Prediction for 24822 user_id for item_id 29 is 1.6662655134753321
# Prediction for 24822 user_id for item_id 32 is 1.0533612258413112
# Prediction for 24822 user_id for item_id 36 is 1.5579709014441907
# Prediction for 24822 user_id for item_id 39 is 0.7472596879478853
# Prediction for 24822 user_id for item_id 40 is 1.0645411838046115
# Prediction for 24822 user_id for item_id 42 is 0.5396681243307346
# Prediction for 24822 user_id for item_id 43 is 0.6895407481234648
# Prediction for 24822 user_id for item_id 50 is 0.9325224270514723
# Prediction for 24822 user_id for item_id 51 is 1.3733443677417971
# Prediction for 24822 user_id for item_id 54 is 1.1462419171132965
# Prediction for 24822 user_id for item_id 56 is 1.3542705593919397
# Prediction for 24822 user_id for item_id 57 is 0.8936143186813615
# Prediction for 24822 user_id for item_id 58 is 1.2524167989437556
# Prediction for 24822 user_id for item_id 59 is 1.5689833346962512
# Prediction for 24822 user_id for item_id 62 is 1.512134060735616
# Prediction for 24822 user_id for item_id 63 is 1.2724388696314894
# Prediction for 24822 user_id for item_id 66 is 0.7910945720262471
# Prediction for 24822 user_id for item_id 69 is 0.6981626352022501
# Prediction for 24822 user_id for item_id 70 is 1.4376964327737523
# Prediction for 24822 user_id for item_id 71 is 1.177140058727422
# Prediction for 24822 user_id for item_id 72 is 1.7323698734009407
# Prediction for 24822 user_id for item_id 73 is 1.3335826366829564
# Prediction for 24822 user_id for item_id 75 is 1.6879263748732392
# Prediction for 24822 user_id for item_id 76 is 1.0799865331534153
# Prediction for 24822 user_id for item_id 77 is 0.5984466880574937
# Prediction for 24822 user_id for item_id 78 is 1.1651196682812215
# Prediction for 24822 user_id for item_id 79 is 0.7175663009388435
# Prediction for 24822 user_id for item_id 80 is 0.73490645332584
# Prediction for 24822 user_id for item_id 81 is 0.5635670992229146
# Prediction for 24822 user_id for item_id 82 is 1.1802156508571904
# Prediction for 24822 user_id for item_id 83 is 0.7739848768498683
# Prediction for 24822 user_id for item_id 84 is 1.3766497245614628
# Prediction for 24822 user_id for item_id 85 is 1.5623077372206013
# Prediction for 24822 user_id for item_id 86 is 0.9092461966684817
# Prediction for 24822 user_id for item_id 87 is 1.508363058457188
# Prediction for 24822 user_id for item_id 88 is 0.8106171975730901
# Prediction for 24822 user_id for item_id 89 is 0.4724406209944424
# Prediction for 24822 user_id for item_id 90 is 0.5545800358071103
# Prediction for 24822 user_id for item_id 91 is 1.4235094424419545
# Prediction for 24822 user_id for item_id 92 is 1.1774805098903318
# Prediction for 24822 user_id for item_id 93 is 1.05674035563653
# Prediction for 24822 user_id for item_id 94 is 0.655161120728295
# Prediction for 24822 user_id for item_id 95 is 0.885512081684574
# Prediction for 24822 user_id for item_id 96 is 1.0007804564988922
# Prediction for 24822 user_id for item_id 97 is 0.46982899713947723
# Prediction for 24822 user_id for item_id 98 is 0.3666302897486362
# Prediction for 24822 user_id for item_id 99 is 1.1381494613925116
# Prediction for 24823 user_id for item_id 57 is 1.1128513471284514
# Prediction for 24823 user_id for item_id 70 is 1.4882072866541194
# Prediction for 24823 user_id for item_id 71 is 1.034753168555761
# Prediction for 24823 user_id for item_id 72 is 1.4869464557342862
# Prediction for 24823 user_id for item_id 73 is 1.4159952508591576
# Prediction for 24823 user_id for item_id 74 is 1.2350646455324403
# Prediction for 24823 user_id for item_id 75 is 1.6529861533107484
# Prediction for 24823 user_id for item_id 76 is 1.1639117344598673
# Prediction for 24823 user_id for item_id 77 is 0.7728005526846606
# Prediction for 24823 user_id for item_id 78 is 1.3382843952454
# Prediction for 24823 user_id for item_id 79 is 0.8420502821411021
# Prediction for 24823 user_id for item_id 80 is 0.6063682689785315
# Prediction for 24823 user_id for item_id 81 is 0.5603129960394527
# Prediction for 24823 user_id for item_id 82 is 1.137578781474605
# Prediction for 24823 user_id for item_id 83 is 0.6796450560874135
# Prediction for 24823 user_id for item_id 84 is 1.4179201297828923
# Prediction for 24823 user_id for item_id 85 is 1.4087175945624497
# Prediction for 24823 user_id for item_id 86 is 0.8717733249578579
# Prediction for 24823 user_id for item_id 87 is 1.5962447124551096
# Prediction for 24823 user_id for item_id 88 is 0.8690032329774481
# Prediction for 24823 user_id for item_id 89 is 0.6712037549749099
# Prediction for 24823 user_id for item_id 90 is 0.7424275287480138
# Prediction for 24823 user_id for item_id 91 is 1.1143985752180485
# Prediction for 24823 user_id for item_id 92 is 1.3373322744760656
# Prediction for 24823 user_id for item_id 93 is 0.9327702281135808
# Prediction for 24823 user_id for item_id 94 is 0.6978408864875957
# Prediction for 24823 user_id for item_id 95 is 1.0657956076827704
# Prediction for 24823 user_id for item_id 97 is 0.5748362585545537
# Prediction for 24823 user_id for item_id 98 is 0.5290664362343418
# Prediction for 24823 user_id for item_id 99 is 1.3050222305058896
# Prediction for 24825 user_id for item_id 0 is 0.6126292115433344
# Prediction for 24825 user_id for item_id 1 is 0.994365642545455
# Prediction for 24825 user_id for item_id 2 is 0.8974089021173888
# Prediction for 24825 user_id for item_id 3 is 0.8694268827744057
# Prediction for 24825 user_id for item_id 8 is 0.5112234561777513
# Prediction for 24825 user_id for item_id 23 is 0.740669716148897
# Prediction for 24825 user_id for item_id 36 is 0.9754889586637915
# Prediction for 24825 user_id for item_id 42 is 0.33995149585635165
# Prediction for 24825 user_id for item_id 43 is 0.37136320403873585
# Prediction for 24825 user_id for item_id 56 is 0.6832925986429288
# Prediction for 24825 user_id for item_id 57 is 0.8471956179733103
# Prediction for 24825 user_id for item_id 59 is 1.1652220044818227
# Prediction for 24825 user_id for item_id 70 is 1.0530507931139101
# Prediction for 24825 user_id for item_id 71 is 0.6652174756094812
# Prediction for 24825 user_id for item_id 72 is 0.7682697815796128
# Prediction for 24825 user_id for item_id 74 is 0.8698832771904755
# Prediction for 24825 user_id for item_id 75 is 1.219040036004717
# Prediction for 24825 user_id for item_id 77 is 0.7578250368751982
# Prediction for 24825 user_id for item_id 78 is 1.0222705991727021
# Prediction for 24825 user_id for item_id 79 is 0.6514199682897668
# Prediction for 24825 user_id for item_id 80 is 0.2781826729619223
# Prediction for 24825 user_id for item_id 81 is 0.413289560742655
# Prediction for 24825 user_id for item_id 82 is 0.5152972750066389
# Prediction for 24825 user_id for item_id 83 is 0.3104481163044261
# Prediction for 24825 user_id for item_id 85 is 0.9170560097800379
# Prediction for 24825 user_id for item_id 86 is 0.6041397203188591
# Prediction for 24825 user_id for item_id 87 is 1.0881806458189895
# Prediction for 24825 user_id for item_id 88 is 0.6438561698749368
# Prediction for 24825 user_id for item_id 89 is 0.5846620457739717
# Prediction for 24825 user_id for item_id 90 is 0.6391971739520709
# Prediction for 24825 user_id for item_id 91 is 0.5275642313800597
# Prediction for 24825 user_id for item_id 92 is 1.1835067088503741
# Prediction for 24825 user_id for item_id 93 is 0.6568491372068535
# Prediction for 24825 user_id for item_id 94 is 0.4538414674157346
# Prediction for 24825 user_id for item_id 95 is 0.9936234448925759
# Prediction for 24825 user_id for item_id 96 is 0.9049666071317529
# Prediction for 24825 user_id for item_id 97 is 0.32265182834104966
# Prediction for 24825 user_id for item_id 98 is 0.4355336433960464
# Prediction for 24825 user_id for item_id 99 is 0.9792034060050965
# Prediction for 24826 user_id for item_id 0 is 0.4602232637456588
# Prediction for 24826 user_id for item_id 1 is 1.1424096622695568
# Prediction for 24826 user_id for item_id 2 is 0.793993586504579
# Prediction for 24826 user_id for item_id 3 is 0.9192014241403538
# Prediction for 24826 user_id for item_id 5 is 0.6234664582300471
# Prediction for 24826 user_id for item_id 8 is 0.5775143819476722
# Prediction for 24826 user_id for item_id 9 is 0.7770423968235736
# Prediction for 24826 user_id for item_id 10 is 0.9423191793825877
# Prediction for 24826 user_id for item_id 11 is 0.7786184905358209
# Prediction for 24826 user_id for item_id 13 is 0.6431137073776516
# Prediction for 24826 user_id for item_id 21 is 1.0181932337741395
# Prediction for 24826 user_id for item_id 22 is 0.7458623205077228
# Prediction for 24826 user_id for item_id 23 is 1.0491053324385051
# Prediction for 24826 user_id for item_id 24 is 0.8343584616380542
# Prediction for 24826 user_id for item_id 25 is 0.8512775737951185
# Prediction for 24826 user_id for item_id 29 is 1.1220464047856438
# Prediction for 24826 user_id for item_id 32 is 0.8540239804996769
# Prediction for 24826 user_id for item_id 33 is 0.9339964514609232
# Prediction for 24826 user_id for item_id 36 is 0.9927782910910875
# Prediction for 24826 user_id for item_id 38 is 0.7435943827415151
# Prediction for 24826 user_id for item_id 39 is 0.6469219008962224
# Prediction for 24826 user_id for item_id 40 is 0.6221592770555222
# Prediction for 24826 user_id for item_id 42 is 0.24386775933129273
# Prediction for 24826 user_id for item_id 43 is 0.3932289778556088
# Prediction for 24826 user_id for item_id 44 is 1.2903686609863483
# Prediction for 24826 user_id for item_id 46 is 0.6553337447460907
# Prediction for 24826 user_id for item_id 50 is 0.7164556188228951
# Prediction for 24826 user_id for item_id 51 is 1.1501332319244644
# Prediction for 24826 user_id for item_id 54 is 0.5886879867496548
# Prediction for 24826 user_id for item_id 57 is 0.9180746382324243
# Prediction for 24826 user_id for item_id 58 is 0.7096887036488516
# Prediction for 24826 user_id for item_id 62 is 1.1791052555193327
# Prediction for 24826 user_id for item_id 63 is 0.9068386083176779
# Prediction for 24826 user_id for item_id 66 is 0.934424399586187
# Prediction for 24826 user_id for item_id 69 is 0.37686446343490476
# Prediction for 24826 user_id for item_id 71 is 0.7410326890910492
# Prediction for 24826 user_id for item_id 72 is 1.0624412956732037
# Prediction for 24826 user_id for item_id 73 is 0.8120391391087469
# Prediction for 24826 user_id for item_id 74 is 0.7365825858215078
# Prediction for 24826 user_id for item_id 75 is 1.1088743625824804
# Prediction for 24826 user_id for item_id 76 is 0.774439224558995
# Prediction for 24826 user_id for item_id 77 is 0.6408423842607491
# Prediction for 24826 user_id for item_id 78 is 1.1902966098072774
# Prediction for 24826 user_id for item_id 79 is 0.8273858948145721
# Prediction for 24826 user_id for item_id 80 is 0.28111548842241485
# Prediction for 24826 user_id for item_id 81 is 0.5283373712928883
# Prediction for 24826 user_id for item_id 82 is 0.576981850820905
# Prediction for 24826 user_id for item_id 83 is 0.33286493519778737
# Prediction for 24826 user_id for item_id 85 is 1.0170782755392236
# Prediction for 24826 user_id for item_id 86 is 0.7610253835977683
# Prediction for 24826 user_id for item_id 87 is 1.1761348784614467
# Prediction for 24826 user_id for item_id 88 is 0.5357935110510648
# Prediction for 24826 user_id for item_id 89 is 0.6128513082233662
# Prediction for 24826 user_id for item_id 90 is 0.5663716902957691
# Prediction for 24826 user_id for item_id 91 is 0.6685320668921344
# Prediction for 24826 user_id for item_id 92 is 1.3278045681901143
# Prediction for 24826 user_id for item_id 93 is 0.805582160086765
# Prediction for 24826 user_id for item_id 94 is 0.43985907413503594
# Prediction for 24826 user_id for item_id 95 is 0.9902937517995525
# Prediction for 24826 user_id for item_id 96 is 0.8345041653754641
# Prediction for 24826 user_id for item_id 97 is 0.41358710859821685
# Prediction for 24826 user_id for item_id 98 is 0.49070008530539044
# Prediction for 24826 user_id for item_id 99 is 0.8286871465820909
# Prediction for 24827 user_id for item_id 0 is 0.6154863389412817
# Prediction for 24827 user_id for item_id 1 is 1.6864210321921276
# Prediction for 24827 user_id for item_id 2 is 1.1154513244651438
# Prediction for 24827 user_id for item_id 3 is 1.3832648727342116
# Prediction for 24827 user_id for item_id 8 is 0.9072423210598362
# Prediction for 24827 user_id for item_id 9 is 1.1617138914361296
# Prediction for 24827 user_id for item_id 23 is 1.6831362277051307
# Prediction for 24827 user_id for item_id 29 is 1.74142176002137
# Prediction for 24827 user_id for item_id 32 is 1.2809096557637383
# Prediction for 24827 user_id for item_id 36 is 1.4392351237050278
# Prediction for 24827 user_id for item_id 42 is 0.3354100945128156
# Prediction for 24827 user_id for item_id 43 is 0.59779791389587
# Prediction for 24827 user_id for item_id 50 is 1.1030657368393832
# Prediction for 24827 user_id for item_id 54 is 0.8491864493437317
# Prediction for 24827 user_id for item_id 56 is 1.1195872153347408
# Prediction for 24827 user_id for item_id 57 is 1.3911610738754392
# Prediction for 24827 user_id for item_id 63 is 1.4209996596987646
# Prediction for 24827 user_id for item_id 66 is 1.3683124971657818
# Prediction for 24827 user_id for item_id 69 is 0.594952602099953
# Prediction for 24827 user_id for item_id 71 is 1.0932130422976964
# Prediction for 24827 user_id for item_id 72 is 1.679465188502567
# Prediction for 24827 user_id for item_id 73 is 1.185220349821823
# Prediction for 24827 user_id for item_id 74 is 1.0323597235741258
# Prediction for 24827 user_id for item_id 75 is 1.5505555804267857
# Prediction for 24827 user_id for item_id 76 is 1.0980906799562304
# Prediction for 24827 user_id for item_id 77 is 0.8668615216543052
# Prediction for 24827 user_id for item_id 78 is 1.807828599068771
# Prediction for 24827 user_id for item_id 79 is 1.2781099782584457
# Prediction for 24827 user_id for item_id 80 is 0.42498046136158835
# Prediction for 24827 user_id for item_id 81 is 0.8044982762658041
# Prediction for 24827 user_id for item_id 83 is 0.5203214425874958
# Prediction for 24827 user_id for item_id 84 is 1.4849258131492384
# Prediction for 24827 user_id for item_id 85 is 1.504592466437793
# Prediction for 24827 user_id for item_id 86 is 1.1590334962395716
# Prediction for 24827 user_id for item_id 87 is 1.772922262570635
# Prediction for 24827 user_id for item_id 89 is 0.9131416457403296
# Prediction for 24827 user_id for item_id 90 is 0.8052972137059056
# Prediction for 24827 user_id for item_id 91 is 1.0306800421408393
# Prediction for 24827 user_id for item_id 92 is 1.9500159570402613
# Prediction for 24827 user_id for item_id 93 is 1.1993500257514567
# Prediction for 24827 user_id for item_id 94 is 0.6551385082551193
# Prediction for 24827 user_id for item_id 95 is 1.4094195434577461
# Prediction for 24827 user_id for item_id 96 is 1.1773787567165337
# Prediction for 24827 user_id for item_id 97 is 0.6812095708296809
# Prediction for 24827 user_id for item_id 98 is 0.7513178005271716
# Prediction for 24827 user_id for item_id 99 is 1.1704953487252894
# Prediction for 24828 user_id for item_id 0 is 0.19472563686557617
# Prediction for 24828 user_id for item_id 1 is 0.7653733256422948
# Prediction for 24828 user_id for item_id 2 is 0.7133982489565727
# Prediction for 24828 user_id for item_id 3 is 0.5264276872679557
# Prediction for 24828 user_id for item_id 5 is 0.4969576175696607
# Prediction for 24828 user_id for item_id 8 is 0.5966612579533932
# Prediction for 24828 user_id for item_id 9 is 0.6605577680515232
# Prediction for 24828 user_id for item_id 10 is 0.6292349976473736
# Prediction for 24828 user_id for item_id 11 is 0.7219108845585183
# Prediction for 24828 user_id for item_id 13 is 0.33187311920337903
# Prediction for 24828 user_id for item_id 21 is 0.8479563508135071
# Prediction for 24828 user_id for item_id 22 is 0.6416915211566058
# Prediction for 24828 user_id for item_id 23 is 1.1290020384191113
# Prediction for 24828 user_id for item_id 24 is 0.645637019604989
# Prediction for 24828 user_id for item_id 25 is 0.7375523006350647
# Prediction for 24828 user_id for item_id 29 is 1.040459442788394
# Prediction for 24828 user_id for item_id 32 is 0.6643118243092558
# Prediction for 24828 user_id for item_id 36 is 0.8874788712858751
# Prediction for 24828 user_id for item_id 38 is 0.5659302735725489
# Prediction for 24828 user_id for item_id 39 is 0.589819065143647
# Prediction for 24828 user_id for item_id 40 is 0.49636241290795335
# Prediction for 24828 user_id for item_id 44 is 0.829661103184547
# Prediction for 24828 user_id for item_id 46 is 0.35416463453425445
# Prediction for 24828 user_id for item_id 50 is 0.5315378884168139
# Prediction for 24828 user_id for item_id 51 is 0.8507319347263729
# Prediction for 24828 user_id for item_id 54 is 0.49403758911599577
# Prediction for 24828 user_id for item_id 57 is 0.5618627456199347
# Prediction for 24828 user_id for item_id 58 is 0.768476186192659
# Prediction for 24828 user_id for item_id 59 is 0.9110556184253447
# Prediction for 24828 user_id for item_id 63 is 0.8666065959916704
# Prediction for 24828 user_id for item_id 66 is 0.5308685362574306
# Prediction for 24828 user_id for item_id 69 is 0.3391239980379793
# Prediction for 24828 user_id for item_id 70 is 0.789157175443163
# Prediction for 24828 user_id for item_id 71 is 0.7124065928407635
# Prediction for 24828 user_id for item_id 72 is 1.1115326043782987
# Prediction for 24828 user_id for item_id 73 is 0.6261737988979151
# Prediction for 24828 user_id for item_id 74 is 0.5667328719244298
# Prediction for 24828 user_id for item_id 75 is 0.8965837058812888
# Prediction for 24828 user_id for item_id 77 is 0.3218344938288462
# Prediction for 24828 user_id for item_id 78 is 0.8034922064555006
# Prediction for 24828 user_id for item_id 79 is 0.553149748784723
# Prediction for 24828 user_id for item_id 80 is 0.366159615197789
# Prediction for 24828 user_id for item_id 81 is 0.41641454889038343
# Prediction for 24828 user_id for item_id 82 is 0.5916686131088446
# Prediction for 24828 user_id for item_id 83 is 0.39060061015502856
# Prediction for 24828 user_id for item_id 84 is 0.7784902208607617
# Prediction for 24828 user_id for item_id 85 is 0.9449388854576499
# Prediction for 24828 user_id for item_id 86 is 0.6355022837444035
# Prediction for 24828 user_id for item_id 88 is 0.38117486465874284
# Prediction for 24828 user_id for item_id 89 is 0.3149921453301217
# Prediction for 24828 user_id for item_id 90 is 0.28620420379117806
# Prediction for 24828 user_id for item_id 91 is 0.8354451853428948
# Prediction for 24828 user_id for item_id 92 is 0.8661200677961883
# Prediction for 24828 user_id for item_id 93 is 0.727226442834631
# Prediction for 24828 user_id for item_id 94 is 0.3372227100207479
# Prediction for 24828 user_id for item_id 95 is 0.5847119502753537
# Prediction for 24828 user_id for item_id 96 is 0.5525329918721618
# Prediction for 24828 user_id for item_id 97 is 0.28659577919673057
# Prediction for 24828 user_id for item_id 98 is 0.2585943245189907
# Prediction for 24828 user_id for item_id 99 is 0.532834470464117
# Prediction for 24830 user_id for item_id 8 is 0.8146005595083019
# Prediction for 24830 user_id for item_id 23 is 1.421492062229826
# Prediction for 24830 user_id for item_id 36 is 1.3529327912096585
# Prediction for 24830 user_id for item_id 43 is 0.5575309414880617
# Prediction for 24830 user_id for item_id 56 is 1.0102764729300688
# Prediction for 24830 user_id for item_id 57 is 1.4743622798829796
# Prediction for 24830 user_id for item_id 66 is 1.472421729838471
# Prediction for 24830 user_id for item_id 70 is 1.5097392706838686
# Prediction for 24830 user_id for item_id 71 is 0.9792831062817361
# Prediction for 24830 user_id for item_id 73 is 1.23088787991775
# Prediction for 24830 user_id for item_id 74 is 1.0721401251981535
# Prediction for 24830 user_id for item_id 75 is 1.5429257232112588
# Prediction for 24830 user_id for item_id 76 is 1.1539260668489892
# Prediction for 24830 user_id for item_id 78 is 1.8383794334353465
# Prediction for 24830 user_id for item_id 79 is 1.2867278175251968
# Prediction for 24830 user_id for item_id 80 is 0.33837718210349343
# Prediction for 24830 user_id for item_id 81 is 0.7646204809227432
# Prediction for 24830 user_id for item_id 82 is 0.8596984421019089
# Prediction for 24830 user_id for item_id 83 is 0.4437790287020507
# Prediction for 24830 user_id for item_id 84 is 1.5009367365026567
# Prediction for 24830 user_id for item_id 85 is 1.372091991963349
# Prediction for 24830 user_id for item_id 86 is 1.0834921676734752
# Prediction for 24830 user_id for item_id 87 is 1.769358754179222
# Prediction for 24830 user_id for item_id 88 is 0.7940242482537462
# Prediction for 24830 user_id for item_id 89 is 1.0070351308146364
# Prediction for 24830 user_id for item_id 90 is 0.9204905644104092
# Prediction for 24830 user_id for item_id 91 is 0.7975948275913398
# Prediction for 24830 user_id for item_id 92 is 1.9914113841563321
# Prediction for 24830 user_id for item_id 93 is 1.0808717532659136
# Prediction for 24830 user_id for item_id 94 is 0.6686448800508732
# Prediction for 24830 user_id for item_id 95 is 1.505847253653882
# Prediction for 24830 user_id for item_id 96 is 1.2463544431158171
# Prediction for 24830 user_id for item_id 97 is 0.697025533390599
# Prediction for 24830 user_id for item_id 98 is 0.8175368976287306
# Prediction for 24830 user_id for item_id 99 is 1.2841794478071438
# Prediction for 24831 user_id for item_id 70 is 1.316004706686275
# Prediction for 24831 user_id for item_id 71 is 0.9102555304498389
# Prediction for 24831 user_id for item_id 72 is 1.6043548640216772
# Prediction for 24831 user_id for item_id 73 is 1.0977843040785347
# Prediction for 24831 user_id for item_id 74 is 0.85444147148036
# Prediction for 24831 user_id for item_id 75 is 1.2089333615995335
# Prediction for 24831 user_id for item_id 76 is 0.9325746812469822
# Prediction for 24831 user_id for item_id 77 is 0.6705284214767334
# Prediction for 24831 user_id for item_id 78 is 1.7273854655323635
# Prediction for 24831 user_id for item_id 79 is 1.2507006107356653
# Prediction for 24831 user_id for item_id 80 is 0.3733073289121169
# Prediction for 24831 user_id for item_id 81 is 0.7351892021400918
# Prediction for 24831 user_id for item_id 82 is 1.017783856249416
# Prediction for 24831 user_id for item_id 83 is 0.5085233105963899
# Prediction for 24831 user_id for item_id 84 is 1.2401607190136372
# Prediction for 24831 user_id for item_id 85 is 1.2764858803040546
# Prediction for 24831 user_id for item_id 86 is 1.055150035674676
# Prediction for 24831 user_id for item_id 87 is 1.6729335119470317
# Prediction for 24831 user_id for item_id 89 is 0.8819076021390372
# Prediction for 24831 user_id for item_id 90 is 0.7248915386952082
# Prediction for 24831 user_id for item_id 91 is 0.8975502312329662
# Prediction for 24831 user_id for item_id 92 is 1.7041612852053063
# Prediction for 24831 user_id for item_id 93 is 1.0063403236438024
# Prediction for 24831 user_id for item_id 94 is 0.6212948427379468
# Prediction for 24831 user_id for item_id 95 is 1.178812657634088
# Prediction for 24831 user_id for item_id 96 is 0.9761920705634665
# Prediction for 24831 user_id for item_id 97 is 0.7830527440598009
# Prediction for 24831 user_id for item_id 98 is 0.7631487636420089
# Prediction for 24831 user_id for item_id 99 is 1.024849824967872
# Prediction for 24832 user_id for item_id 70 is 0.9634682019101588
# Prediction for 24832 user_id for item_id 71 is 0.572429665229869
# Prediction for 24832 user_id for item_id 72 is 1.1479496143713852
# Prediction for 24832 user_id for item_id 73 is 1.0420901909190938
# Prediction for 24832 user_id for item_id 74 is 0.7358274930954596
# Prediction for 24832 user_id for item_id 75 is 0.8209478878917329
# Prediction for 24832 user_id for item_id 76 is 0.7090554234563613
# Prediction for 24832 user_id for item_id 77 is 0.3400024730648532
# Prediction for 24832 user_id for item_id 78 is 1.0491721336182234
# Prediction for 24832 user_id for item_id 79 is 0.7116446817210471
# Prediction for 24832 user_id for item_id 80 is 0.40989397413949535
# Prediction for 24832 user_id for item_id 81 is 0.38048497088326916
# Prediction for 24832 user_id for item_id 82 is 1.0913410592460064
# Prediction for 24832 user_id for item_id 83 is 0.5427446008790692
# Prediction for 24832 user_id for item_id 84 is 0.8011360019718974
# Prediction for 24832 user_id for item_id 85 is 0.8174668068493594
# Prediction for 24832 user_id for item_id 86 is 0.5898647722662926
# Prediction for 24832 user_id for item_id 87 is 1.2086506216518278
# Prediction for 24832 user_id for item_id 88 is 0.5056260277820008
# Prediction for 24832 user_id for item_id 89 is 0.5458356951068725
# Prediction for 24832 user_id for item_id 90 is 0.5080418629305181
# Prediction for 24832 user_id for item_id 92 is 0.780098176067005
# Prediction for 24832 user_id for item_id 93 is 0.4865158951942719
# Prediction for 24832 user_id for item_id 94 is 0.5352105708167846
# Prediction for 24832 user_id for item_id 95 is 0.5527219647220664
# Prediction for 24832 user_id for item_id 96 is 0.6148442944995074
# Prediction for 24832 user_id for item_id 97 is 0.6744031303376089
# Prediction for 24832 user_id for item_id 98 is 0.49472403834168543
# Prediction for 24832 user_id for item_id 99 is 0.8598947824925953
# Prediction for 24833 user_id for item_id 70 is 1.344096431958833
# Prediction for 24833 user_id for item_id 71 is 0.6697461672459422
# Prediction for 24833 user_id for item_id 72 is 1.1284875764763562
# Prediction for 24833 user_id for item_id 73 is 1.259393001108166
# Prediction for 24833 user_id for item_id 74 is 0.9668642649250672
# Prediction for 24833 user_id for item_id 75 is 1.1815789586876804
# ...
# Prediction for 24976 user_id for item_id 74 is 0.7656454040819684
# Prediction for 24976 user_id for item_id 75 is 1.1742183494452307
# Prediction for 24976 user_id for item_id 76 is 0.698547002399328
# Prediction for 24976 user_id for item_id 78 is 0.8375592602285296
# Prediction for 24976 user_id for item_id 79 is 0.5411043957105894
# Prediction for 24976 user_id for item_id 80 is 0.5224961413018375
# Prediction for 24976 user_id for item_id 81 is 0.4513132605003795
# Prediction for 24976 user_id for item_id 82 is 0.7724217049338867
# Prediction for 24976 user_id for item_id 83 is 0.5357758509372764
# Prediction for 24976 user_id for item_id 84 is 0.9592106319952692
# Prediction for 24976 user_id for item_id 85 is 1.1808092729701107
# Prediction for 24976 user_id for item_id 86 is 0.7166625382101299
# Prediction for 24976 user_id for item_id 87 is 1.0429162802598069
# Prediction for 24976 user_id for item_id 88 is 0.5091178009137071
# Prediction for 24976 user_id for item_id 89 is 0.2932120881026647
# Prediction for 24976 user_id for item_id 90 is 0.3154590820384174
# Prediction for 24976 user_id for item_id 91 is 1.1061923863220167
# Prediction for 24976 user_id for item_id 92 is 0.8994726925610169
# Prediction for 24977 user_id for item_id 0 is 0.30753139904793825
# Prediction for 24977 user_id for item_id 1 is 0.9307434535190742
# Prediction for 24977 user_id for item_id 2 is 0.7244530490373577
# Prediction for 24977 user_id for item_id 3 is 0.9829443126731472
# Prediction for 24977 user_id for item_id 5 is 0.5249928817304402
# Prediction for 24977 user_id for item_id 8 is 0.8838791440391215
# Prediction for 24977 user_id for item_id 9 is 0.7005724177781693
# Prediction for 24977 user_id for item_id 11 is 1.106401209739775
# Prediction for 24977 user_id for item_id 13 is 0.514385065387592
# Prediction for 24977 user_id for item_id 21 is 1.2518364841201157
# Prediction for 24977 user_id for item_id 22 is 0.5627850648011468
# Prediction for 24977 user_id for item_id 23 is 1.518119417635503
# Prediction for 24977 user_id for item_id 24 is 0.6230670753559161
# Prediction for 24977 user_id for item_id 25 is 1.1009974685432844
# Prediction for 24977 user_id for item_id 27 is 0.6489797241254612
# Prediction for 24977 user_id for item_id 29 is 1.3995466206216889
# Prediction for 24977 user_id for item_id 32 is 0.8799010251404411
# Prediction for 24977 user_id for item_id 33 is 1.1822375968373793
# Prediction for 24977 user_id for item_id 36 is 0.9229159324828244
# Prediction for 24977 user_id for item_id 37 is 0.8192472350754074
# Prediction for 24977 user_id for item_id 38 is 0.6051808048146462
# Prediction for 24977 user_id for item_id 39 is 0.7351539348671584
# Prediction for 24977 user_id for item_id 40 is 0.7567826278208226
# Prediction for 24977 user_id for item_id 42 is 0.28225454766845814
# Prediction for 24977 user_id for item_id 44 is 1.2624128354143924
# Prediction for 24977 user_id for item_id 46 is 0.6699252934188479
# Prediction for 24977 user_id for item_id 50 is 0.9253432215563212
# Prediction for 24977 user_id for item_id 51 is 0.7885424657176562
# Prediction for 24977 user_id for item_id 54 is 0.7380037835116497
# Prediction for 24977 user_id for item_id 56 is 0.9389676884267386
# Prediction for 24977 user_id for item_id 57 is 1.0166416636389697
# Prediction for 24977 user_id for item_id 58 is 1.11059519137994
# Prediction for 24977 user_id for item_id 59 is 0.9533488112293662
# Prediction for 24977 user_id for item_id 62 is 1.172491094315687
# Prediction for 24977 user_id for item_id 63 is 1.0989307021130459
# Prediction for 24977 user_id for item_id 66 is 0.8001301540485312
# Prediction for 24977 user_id for item_id 69 is 0.6291259289688643
# Prediction for 24977 user_id for item_id 71 is 0.7149412987237181
# Prediction for 24977 user_id for item_id 72 is 1.4088294134940975
# Prediction for 24977 user_id for item_id 74 is 0.6832124302620259
# Prediction for 24977 user_id for item_id 75 is 0.8750849506421899
# Prediction for 24977 user_id for item_id 76 is 0.6965804659569945
# Prediction for 24977 user_id for item_id 77 is 0.3481167586772748
# Prediction for 24977 user_id for item_id 78 is 1.2456485403869935
# Prediction for 24977 user_id for item_id 79 is 0.8918795967427404
# Prediction for 24977 user_id for item_id 80 is 0.4100988106074871
# Prediction for 24977 user_id for item_id 81 is 0.5210245007313581
# Prediction for 24977 user_id for item_id 83 is 0.538037487168261
# Prediction for 24977 user_id for item_id 84 is 0.884198374256101
# Prediction for 24977 user_id for item_id 85 is 0.999625616923256
# Prediction for 24977 user_id for item_id 86 is 0.7798750416551529
# Prediction for 24977 user_id for item_id 87 is 1.3189001563186207
# Prediction for 24977 user_id for item_id 88 is 0.46386384888366716
# Prediction for 24977 user_id for item_id 89 is 0.5966837212596122
# Prediction for 24977 user_id for item_id 90 is 0.48686256817756535
# Prediction for 24977 user_id for item_id 91 is 0.8582702665832455
# Prediction for 24977 user_id for item_id 92 is 1.0596727825038659
# Prediction for 24977 user_id for item_id 93 is 0.7138773404215744
# Prediction for 24977 user_id for item_id 94 is 0.5253323242500083
# Prediction for 24977 user_id for item_id 95 is 0.687195973782826
# Prediction for 24977 user_id for item_id 96 is 0.652884105253619
# Prediction for 24977 user_id for item_id 97 is 0.6919691573827184
# Prediction for 24977 user_id for item_id 98 is 0.5444214501411277
# Prediction for 24977 user_id for item_id 99 is 0.7826010749264816
# Prediction for 24979 user_id for item_id 70 is 0.9095428244023879
# Prediction for 24979 user_id for item_id 71 is 0.41789050931487104
# Prediction for 24979 user_id for item_id 72 is 0.8348263987819612
# Prediction for 24979 user_id for item_id 73 is 0.9431243360452518
# Prediction for 24979 user_id for item_id 74 is 0.6634842567176888
# Prediction for 24979 user_id for item_id 76 is 0.7008562475922638
# Prediction for 24979 user_id for item_id 77 is 0.4932731032965182
# Prediction for 24979 user_id for item_id 78 is 1.155493341635621
# Prediction for 24979 user_id for item_id 79 is 0.8069022796532659
# Prediction for 24980 user_id for item_id 0 is 0.7438158638250764
# Prediction for 24980 user_id for item_id 1 is 1.2873247731101958
# Prediction for 24980 user_id for item_id 2 is 1.3512667309049624
# Prediction for 24980 user_id for item_id 3 is 1.5370422339509817
# Prediction for 24980 user_id for item_id 5 is 1.0001125731265532
# Prediction for 24980 user_id for item_id 8 is 1.3530618258805633
# Prediction for 24980 user_id for item_id 9 is 0.9187407608513768
# Prediction for 24980 user_id for item_id 10 is 1.0881401841849496
# Prediction for 24980 user_id for item_id 11 is 1.6121763401080034
# Prediction for 24980 user_id for item_id 21 is 1.8158334557402087
# Prediction for 24980 user_id for item_id 22 is 0.677467102177717
# Prediction for 24980 user_id for item_id 23 is 2.0127539989943233
# Prediction for 24980 user_id for item_id 24 is 0.8678980931566846
# Prediction for 24980 user_id for item_id 29 is 1.9558154334857816
# Prediction for 24980 user_id for item_id 32 is 1.2991515585086166
# Prediction for 24980 user_id for item_id 33 is 1.8249432457103192
# Prediction for 24980 user_id for item_id 36 is 1.4850240943744815
# Prediction for 24980 user_id for item_id 38 is 1.2731830984170516
# Prediction for 24980 user_id for item_id 39 is 0.83804771333195
# Prediction for 24980 user_id for item_id 42 is 0.6170417974424365
# Prediction for 24980 user_id for item_id 43 is 0.8056862337565618
# Prediction for 24980 user_id for item_id 44 is 1.9055278669057505
# Prediction for 24980 user_id for item_id 51 is 1.2911888220082552
# Prediction for 24980 user_id for item_id 54 is 1.4190200678650493
# Prediction for 24980 user_id for item_id 56 is 1.4591266841336326
# Prediction for 24980 user_id for item_id 57 is 1.5595636719788326
# Prediction for 24980 user_id for item_id 58 is 1.4966141133343773
# Prediction for 24980 user_id for item_id 59 is 1.5776435714110382
# Prediction for 24980 user_id for item_id 62 is 1.8304661836366107
# Prediction for 24980 user_id for item_id 63 is 1.409685150770622
# Prediction for 24980 user_id for item_id 66 is 1.2532107989515553
# Prediction for 24980 user_id for item_id 69 is 1.023060018794064
# Prediction for 24980 user_id for item_id 70 is 1.703490882707831
# Prediction for 24980 user_id for item_id 72 is 1.852850258376985
# Prediction for 24980 user_id for item_id 73 is 1.742887562200475
# Prediction for 24980 user_id for item_id 74 is 1.3320324123534575
# Prediction for 24980 user_id for item_id 75 is 1.6051234818724374
# Prediction for 24980 user_id for item_id 76 is 1.2890463155345449
# Prediction for 24980 user_id for item_id 77 is 0.7503898056510833
# Prediction for 24980 user_id for item_id 78 is 1.7797018694907039
# Prediction for 24980 user_id for item_id 79 is 1.1864494262720828
# Prediction for 24980 user_id for item_id 80 is 0.6712782998824777
# Prediction for 24980 user_id for item_id 81 is 0.6721214236522511
# Prediction for 24980 user_id for item_id 82 is 1.645415706921573
# Prediction for 24980 user_id for item_id 83 is 0.8524544825295443
# Prediction for 24980 user_id for item_id 84 is 1.502869873098715
# Prediction for 24980 user_id for item_id 85 is 1.4806285962262133
# Prediction for 24980 user_id for item_id 86 is 1.0310261372358942
# Prediction for 24980 user_id for item_id 87 is 2.029120705995648
# Prediction for 24980 user_id for item_id 88 is 0.9314846308344727
# Prediction for 24980 user_id for item_id 89 is 0.93501217711504
# Prediction for 24980 user_id for item_id 90 is 0.9135974975190035
# Prediction for 24980 user_id for item_id 91 is 1.1882956068988495
# Prediction for 24980 user_id for item_id 92 is 1.5036076733759403
# Prediction for 24980 user_id for item_id 93 is 0.9323743373135176
# Prediction for 24980 user_id for item_id 94 is 0.8869111461800003
# Prediction for 24980 user_id for item_id 95 is 1.1260520776248786
# Prediction for 24980 user_id for item_id 96 is 1.1793141163888776
# Prediction for 24980 user_id for item_id 97 is 0.9990064792944934
# Prediction for 24980 user_id for item_id 98 is 0.8080303750713196
# Prediction for 24980 user_id for item_id 99 is 1.5232753541013846
# Prediction for 24981 user_id for item_id 0 is 0.47210508832861253
# Prediction for 24981 user_id for item_id 1 is 0.7421606061044176
# Prediction for 24981 user_id for item_id 2 is 1.2512641957967578
# Prediction for 24981 user_id for item_id 3 is 0.8121262826804939
# Prediction for 24981 user_id for item_id 5 is 0.8622164575918857
# Prediction for 24981 user_id for item_id 8 is 1.0851888197390103
# Prediction for 24981 user_id for item_id 9 is 0.6930070668102
# Prediction for 24981 user_id for item_id 10 is 0.7857095527657129
# Prediction for 24981 user_id for item_id 11 is 1.177282648640222
# Prediction for 24981 user_id for item_id 13 is 0.6487395562732085
# Prediction for 24981 user_id for item_id 21 is 1.2555406370619115
# Prediction for 24981 user_id for item_id 22 is 0.54979221321202
# Prediction for 24981 user_id for item_id 23 is 1.5991321796861715
# Prediction for 24981 user_id for item_id 24 is 0.6461112791689687
# Prediction for 24981 user_id for item_id 29 is 1.4662691875687812
# Prediction for 24981 user_id for item_id 32 is 0.8979377642574062
# Prediction for 24981 user_id for item_id 33 is 1.2380671698681593
# Prediction for 24981 user_id for item_id 36 is 1.2938702171566698
# Prediction for 24981 user_id for item_id 37 is 0.6237277460281018
# Prediction for 24981 user_id for item_id 39 is 0.5603487207936443
# Prediction for 24981 user_id for item_id 40 is 1.0596854002023615
# Prediction for 24981 user_id for item_id 42 is 0.5460298405007994
# Prediction for 24981 user_id for item_id 43 is 0.6464107677568077
# Prediction for 24981 user_id for item_id 44 is 1.0999122877712897
# Prediction for 24981 user_id for item_id 46 is 0.47256511632718884
# Prediction for 24981 user_id for item_id 50 is 0.9229549879970406
# Prediction for 24981 user_id for item_id 51 is 1.0216581730949816
# Prediction for 24981 user_id for item_id 56 is 1.2349496601875294
# Prediction for 24981 user_id for item_id 57 is 0.8566893746955763
# Prediction for 24981 user_id for item_id 58 is 1.1605837221860051
# Prediction for 24981 user_id for item_id 59 is 1.2746288744779712
# Prediction for 24981 user_id for item_id 62 is 1.3073376105760688
# Prediction for 24981 user_id for item_id 63 is 1.0530512471438174
# Prediction for 24981 user_id for item_id 66 is 0.6630603331533038
# Prediction for 24981 user_id for item_id 69 is 0.7446079530823311
# Prediction for 24981 user_id for item_id 70 is 1.2808644479899656
# Prediction for 24981 user_id for item_id 71 is 0.9442270666961913
# Prediction for 24981 user_id for item_id 72 is 1.488155938068338
# Prediction for 24981 user_id for item_id 73 is 1.3231462340318496
# Prediction for 24981 user_id for item_id 75 is 1.4075023155126811
# Prediction for 24981 user_id for item_id 76 is 0.9771718270879656
# Prediction for 24981 user_id for item_id 77 is 0.4773194999774221
# Prediction for 24981 user_id for item_id 78 is 1.0104269078958055
# Prediction for 24981 user_id for item_id 80 is 0.6784290767440747
# Prediction for 24981 user_id for item_id 81 is 0.43092951806137464
# Prediction for 24981 user_id for item_id 82 is 1.2445162473998623
# Prediction for 24981 user_id for item_id 83 is 0.751541813164154
# Prediction for 24981 user_id for item_id 84 is 1.1573015902973245
# Prediction for 24981 user_id for item_id 85 is 1.2716590449454446
# Prediction for 24981 user_id for item_id 86 is 0.7178359800980347
# Prediction for 24981 user_id for item_id 87 is 1.3770470720023933
# Prediction for 24981 user_id for item_id 88 is 0.7450132814677272
# Prediction for 24981 user_id for item_id 89 is 0.4432756619301176
# Prediction for 24981 user_id for item_id 90 is 0.5314499385898421
# Prediction for 24981 user_id for item_id 91 is 1.197219071681753
# Prediction for 24981 user_id for item_id 92 is 0.8602374434097085
# Prediction for 24981 user_id for item_id 93 is 0.7711760283786824
# Prediction for 24981 user_id for item_id 94 is 0.6385304343355186
# Prediction for 24981 user_id for item_id 95 is 0.666893659963751
# Prediction for 24981 user_id for item_id 96 is 0.8482098828586486
# Prediction for 24981 user_id for item_id 97 is 0.5390306120318553
# Prediction for 24981 user_id for item_id 98 is 0.3637336883037861
# Prediction for 24981 user_id for item_id 99 is 1.0961876011833946
# Prediction for 24982 user_id for item_id 71 is 0.8945358632221284
# Prediction for 24982 user_id for item_id 72 is 1.642495643516858
# Prediction for 24982 user_id for item_id 73 is 1.7946476209649231
# Prediction for 24982 user_id for item_id 74 is 1.3292811140788343
# Prediction for 24982 user_id for item_id 75 is 1.4745739759860534
# Prediction for 24982 user_id for item_id 76 is 1.2627106274459257
# Prediction for 24982 user_id for item_id 77 is 0.700528010639037
# Prediction for 24982 user_id for item_id 78 is 1.6349451644368143
# Prediction for 24982 user_id for item_id 79 is 1.0624099940812946
# Prediction for 24982 user_id for item_id 80 is 0.6543126236082699
# Prediction for 24982 user_id for item_id 81 is 0.5543025448726674
# Prediction for 24982 user_id for item_id 82 is 1.706622238890732
# Prediction for 24982 user_id for item_id 83 is 0.8539247542569066
# Prediction for 24982 user_id for item_id 84 is 1.3831003984131018
# Prediction for 24982 user_id for item_id 85 is 1.2839248166275725
# Prediction for 24982 user_id for item_id 87 is 1.9387463768934505
# Prediction for 24982 user_id for item_id 88 is 0.9319069119728961
# Prediction for 24982 user_id for item_id 89 is 0.9056577746710537
# Prediction for 24982 user_id for item_id 90 is 0.9212591925139552
# Prediction for 24982 user_id for item_id 91 is 1.0324017431867654
# Prediction for 24982 user_id for item_id 92 is 1.2467631791088072
# Prediction for 24982 user_id for item_id 93 is 0.7107031791333747
# Prediction for 24982 user_id for item_id 94 is 0.8927112000730747
# Prediction for 24982 user_id for item_id 95 is 0.977334952894635
# Prediction for 24982 user_id for item_id 96 is 1.1061858417680608
# Prediction for 24982 user_id for item_id 97 is 1.029058658057513
# Prediction for 24982 user_id for item_id 98 is 0.7895288343771494
# Prediction for 24982 user_id for item_id 99 is 1.5557741622096057

# %%
test_idx
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([70, 71, 72, ..., 97, 98, 99]))

# %%
num_iter = 100
hist = sgd(num_iter)  # Note how the MSE decreases with the number of iterations
plt.figure()
plt.plot(np.arange(0, num_iter, 5), hist)
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.show()
# Out:
# Iteration 0/100:	MSE=25.674667
# Iteration 5/100:	MSE=24.482733
# Iteration 10/100:	MSE=23.810884
# Iteration 15/100:	MSE=22.963158

# %%
recom_nan.iloc[55,13]

# %%
df_items = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true')
df_users = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true', sheet_name=1)

# %%
df_users.set_index('User', inplace=True)

# %%
df_items[df_items['Factor15'] == df_items['Factor15'].min()]

# %%
items_latent = df_items.drop('Title', axis=1).values

# %%
user_latent = df_users.values

# %%
user_latent.shape

# %%
items_latent.shape

# %%
def predict_movie_rating(user, movie):
  user_arr = df_users.loc[user].values
  movie_arr = df_items.loc[movie].drop('Title').values
  return user_arr.dot(movie_arr)

# %%
def top_n_recommendation(user, n):
  pred = {}
  for movie in df_items.index:
    pred[movie] = predict_movie_rating(user, movie)
  pred = dict(sorted(pred.items(), key=lambda kv: kv[1], reverse=True))
  movies = list(pred.keys())
  return movies[:n]

# %%
predict_movie_rating(783, 807)

# %%
predict_movie_rating(156, 9331)

# %%
top_n_recommendation(4940, 3)

# %%
df_items.loc[top_n_recommendation(1882, 2)]['Title']
